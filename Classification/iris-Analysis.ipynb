# %%
from urllib.request import urlretrieve
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
iris = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

# %%
urlretrieve(iris)
# Out:
# ('/tmp/tmp8hkbx9b5', <http.client.HTTPMessage at 0x7f741da1f438>)

# %%
data=load_iris()

# %%
from IPython.display import Image
Image(filename='iris1.JPG')

# %%
x1=[]
x2=[]
x3=[]
x4=[]
for i in data['data']:
    #print(i[4])
    x1.append(i[0])
    x2.append(i[1])
    x3.append(i[2])
    x4.append(i[3])

# %%
#conda install -c plotly chart-studio

# %%
import pandas as pd
df=pd.DataFrame({'X1':x1,'X2':x2,'X3':x3,'X4':x4})

# %%
df
# Out:
#       X1   X2   X3   X4
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# 5    5.4  3.9  1.7  0.4
# 6    4.6  3.4  1.4  0.3
# 7    5.0  3.4  1.5  0.2
# 8    4.4  2.9  1.4  0.2
# 9    4.9  3.1  1.5  0.1
# 10   5.4  3.7  1.5  0.2
# 11   4.8  3.4  1.6  0.2
# 12   4.8  3.0  1.4  0.1
# 13   4.3  3.0  1.1  0.1
# 14   5.8  4.0  1.2  0.2
# 15   5.7  4.4  1.5  0.4
# 16   5.4  3.9  1.3  0.4
# 17   5.1  3.5  1.4  0.3
# 18   5.7  3.8  1.7  0.3
# 19   5.1  3.8  1.5  0.3
# 20   5.4  3.4  1.7  0.2
# 21   5.1  3.7  1.5  0.4
# 22   4.6  3.6  1.0  0.2
# 23   5.1  3.3  1.7  0.5
# 24   4.8  3.4  1.9  0.2
# 25   5.0  3.0  1.6  0.2
# 26   5.0  3.4  1.6  0.4
# 27   5.2  3.5  1.5  0.2
# 28   5.2  3.4  1.4  0.2
# 29   4.7  3.2  1.6  0.2
# ..   ...  ...  ...  ...
# 120  6.9  3.2  5.7  2.3
# 121  5.6  2.8  4.9  2.0
# 122  7.7  2.8  6.7  2.0
# 123  6.3  2.7  4.9  1.8
# 124  6.7  3.3  5.7  2.1
# 125  7.2  3.2  6.0  1.8
# ...

# %%
df['Target']=data['target']

# %%
df
# Out:
#       X1   X2   X3   X4  Target
# 0    5.1  3.5  1.4  0.2       0
# 1    4.9  3.0  1.4  0.2       0
# 2    4.7  3.2  1.3  0.2       0
# 3    4.6  3.1  1.5  0.2       0
# 4    5.0  3.6  1.4  0.2       0
# 5    5.4  3.9  1.7  0.4       0
# 6    4.6  3.4  1.4  0.3       0
# 7    5.0  3.4  1.5  0.2       0
# 8    4.4  2.9  1.4  0.2       0
# 9    4.9  3.1  1.5  0.1       0
# 10   5.4  3.7  1.5  0.2       0
# 11   4.8  3.4  1.6  0.2       0
# 12   4.8  3.0  1.4  0.1       0
# 13   4.3  3.0  1.1  0.1       0
# 14   5.8  4.0  1.2  0.2       0
# 15   5.7  4.4  1.5  0.4       0
# 16   5.4  3.9  1.3  0.4       0
# 17   5.1  3.5  1.4  0.3       0
# 18   5.7  3.8  1.7  0.3       0
# 19   5.1  3.8  1.5  0.3       0
# 20   5.4  3.4  1.7  0.2       0
# 21   5.1  3.7  1.5  0.4       0
# 22   4.6  3.6  1.0  0.2       0
# 23   5.1  3.3  1.7  0.5       0
# 24   4.8  3.4  1.9  0.2       0
# 25   5.0  3.0  1.6  0.2       0
# 26   5.0  3.4  1.6  0.4       0
# 27   5.2  3.5  1.5  0.2       0
# ...

# %%
df.to_csv('iris.csv')

# %%
df.describe()
# Out:
#                X1          X2          X3          X4      Target
# count  150.000000  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.057333    3.758000    1.199333    1.000000
# std      0.828066    0.435866    1.765298    0.762238    0.819232
# min      4.300000    2.000000    1.000000    0.100000    0.000000
# 25%      5.100000    2.800000    1.600000    0.300000    0.000000
# 50%      5.800000    3.000000    4.350000    1.300000    1.000000
# 75%      6.400000    3.300000    5.100000    1.800000    2.000000
# max      7.900000    4.400000    6.900000    2.500000    2.000000

# %%
attributes = ["sepal_length", "sepal_width", "petal_length", "petal_width", "class"]
df.columns = attributes

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width       class
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.057333      3.758000     1.199333    1.000000
# std        0.828066     0.435866      1.765298     0.762238    0.819232
# min        4.300000     2.000000      1.000000     0.100000    0.000000
# 25%        5.100000     2.800000      1.600000     0.300000    0.000000
# 50%        5.800000     3.000000      4.350000     1.300000    1.000000
# 75%        6.400000     3.300000      5.100000     1.800000    2.000000
# max        7.900000     4.400000      6.900000     2.500000    2.000000

# %%
df['class'].unique()
# Out:
# array([0, 1, 2])

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')

# %%
#classification

# %%
#what algo you will choose

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.catplot(y="sepal_length", x="class", data=df)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
labelencoder = LabelEncoder()
arrclass = LabelEncoder().fit_transform(df.iloc[:, -1])

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.gca(projection='3d')
#ax = fig.add_subplot(111,projec='3d')

x = np.asarray(df["sepal_length"])
y = np.asarray(df["sepal_width"])
z =  np.asarray(arrclass)#
#ax.scatter(xs, ys, zs, edgecolors='w',cmdap='hsv')
ax.scatter3D(x,y,z, c=z,cmap='hsv')
ax.set_xlabel('sepal length')
ax.set_ylabel('sepal width')
ax.set_zlabel('class')

plt.show()

# %%
fig = plt.figure(figsize=(8, 6))
ax = fig.gca(projection='3d')
#ax = fig.add_subplot(111,projec='3d')

x = np.asarray(df["petal_length"])#Alarm
y = np.asarray(df["petal_width"])#Pulse
z =  np.asarray(arrclass)#
#ax.scatter(xs, ys, zs, edgecolors='w',cmdap='hsv')
ax.scatter3D(x,y,z, c=z,cmap='hsv')
ax.set_xlabel('petal length')
ax.set_ylabel('petal width')
ax.set_zlabel('class')

plt.show()

# %%
sns.boxplot(x="class",y="petal_length",data=df)
plt.show()

# %%
sns.violinplot(x="class",y="petal_length",data=df)
plt.show()

# %%
sns.set_style("whitegrid")
sns.pairplot(df,hue="class",size=3);
plt.show()

# %%
from matplotlib import pyplot 
from sklearn.model_selection import KFold 
from sklearn.model_selection import cross_val_score 
from sklearn.linear_model import LogisticRegression 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis 
from sklearn.naive_bayes import GaussianNB 
from sklearn.svm import SVC

# %%
array = df.values    
X = array[:,0:4]    
Y = array[:,4]

# %%
models = [] 
models.append(( 'LR' , LogisticRegression()))
models.append(( 'LDA' , LinearDiscriminantAnalysis())) 
models.append(( 'KNN' , KNeighborsClassifier())) 
models.append(( 'CART' , DecisionTreeClassifier()))
models.append(( 'NB' , GaussianNB())) 
models.append(( 'SVM' , SVC()))

# %%
 
results = [] 
names = [] 
scoring = 'accuracy' 
for name, model in models:
        kfold = KFold(n_splits=10, random_state=7) 
        cv_results = cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
        results.append(cv_results)
        names.append(name)
        msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std()) 
        print(msg)
# Out:
# LR: 0.880000 (0.148474)
# LDA: 0.966667 (0.061464)
# KNN: 0.933333 (0.084327)
# CART: 0.940000 (0.069602)
# NB: 0.946667 (0.058119)
# SVM: 0.953333 (0.052068)

# %%
fig = pyplot.figure()
fig.suptitle( 'Algorithm Comparison' ) 
ax = fig.add_subplot(111) 
pyplot.boxplot(results) 
ax.set_xticklabels(names)
pyplot.show()
